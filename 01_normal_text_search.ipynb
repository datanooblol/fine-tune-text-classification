# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from package.utils import load_keywords

config = load_keywords(config_path="./keywords.config.yaml")
keywords = config["keywords"]
keywords
# Out:
# ['machine learning',
#  'artificial intelligence',
#  'data science',
#  'neural networks',
#  'การเรียนรู้ของเครื่อง',
#  'ปัญญาประดิษฐ์',
#  'วิทยาศาสตร์ข้อมูล',
#  'โครงข่ายประสาทเทียม']

# %%
texts = [
    "This is a sample text containing machine learning and artificial intelligence.",
    "Another text about deep learning and neural networks.",
    "This is clear and concise text without any technical terms.",
    "machne lerning is cool",
    "artifical inteligence",
    "text"
]

texts = [
    "นี่คือข้อความตัวอย่างที่มีเนื้อหาเกี่ยวกับการเรียนรู้ของเครื่องและปัญญาประดิษฐ์",
    "ข้อความอื่นเกี่ยวกับการเรียนรู้เชิงลึกและโครงข่ายประสาทเทียม",
    "นี่คือข้อความที่ชัดเจนและกระชับโดยไม่มีคำศัพท์ทางเทคนิคใดๆ",
    "การเรยนรู้ของเครื่องนั้นเจ๋งมาก",
    "ปัญญาประดิษท์",
    "ข้อความ"
]

# %%
from package.utils import contains_keyword
for text in texts:
    print(contains_keyword(text, keywords))
# Out:
# True
# True
# False
# False
# False
# False

# %%
from package.utils import contains_keyword_fuzzy
for text in texts:
    print(contains_keyword_fuzzy(text, keywords, threshold=80))
# Out:
# True
# True
# False
# True
# True
# False
